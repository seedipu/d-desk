# %%
# !pip install -U seaborn==0.10.1

# !pip install -U matplotlib==3.2.2
# Out:
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.0
#     Uninstalling seaborn-0.11.0:
#       Successfully uninstalled seaborn-0.11.0
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.3.2
#     Uninstalling matplotlib-3.3.2:
#       Successfully uninstalled matplotlib-3.3.2
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df= pd.read_csv("startup_funding.csv")

# %%
mydata
# Out:
#                      Startup Name    Industry Vertical  \
# 0                          BYJU’S            Education
# 1                          Shuttl       Transportation
# 2                       Mamaearth            eCommerce
# 3    https://www.wealthbucket.in/              Finance
# 4                          Fashor  Fashion and Apparel
# ..                            ...                  ...
# 982                     Power2SME    Consumer Internet
# 983                     Applicate           Technology
# 984          Zebi (yet to launch)           Technology
# 985                         Truce                 FMCG
# 986                         Qriyo    Consumer Internet
#
#                                            SubVertical City  Location  \
# 0                                           E-learning      Bangalore
# 1                            App based shuttle service       Gurugram
# 2                Retailer of baby and toddler products      Bangalore
# ...

# %%
mydata.tail()
# Out:
#              Startup Name  Industry Vertical  \
# 982             Power2SME  Consumer Internet
# 983             Applicate         Technology
# 984  Zebi (yet to launch)         Technology
# 985                 Truce               FMCG
# 986                 Qriyo  Consumer Internet
#
#                                            SubVertical City  Location  \
# 982                              SME Online Buying Hub       Gurugram
# 983  Sales, Market, Distribution & Data Analytics P...      Bangalore
# 984                      Data Intelligence & Analytics      Hyderabad
# 985                   Vegetables & Fruits Supply Chain         Mumbai
# 986  Online Fitness & Educational information Aggre...        Jodhpur
#
#                                         Investors Name     InvestmentnType  \
# 982  Nandan Nilekani, Accel Partners, Kalaari Capit...      Private Equity
# 983                               Undisclosed Investor  Seed/Angel Funding
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 987 entries, 0 to 986
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Startup Name       987 non-null    object
#  1   Industry Vertical  987 non-null    object
#  2   SubVertical        987 non-null    object
#  3   City  Location     987 non-null    object
#  4   Investors Name     987 non-null    object
#  5   InvestmentnType    987 non-null    object
#  6   Amount in USD      987 non-null    int64
#  7   year_funding       987 non-null    int64
#  8   month_funding      987 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 69.5+ KB

# %%
mydata.shape
# Out:
# (987, 9)

# %%
mydata.describe(include=[object]).T
# Out:
#                   count unique                      top freq
# Startup Name        987    877                 Ola Cabs    4
# Industry Vertical   987     38        Consumer Internet  379
# SubVertical         987    925  Online Lending Platform    9
# City  Location      987     29                Bangalore  327
# Investors Name      987    837     Undisclosed Investor   47
# InvestmentnType     987      9           Private Equity  510

# %%
sns.pointplot(y = df['Amount in USD'],hue = df['year_funding'],markers = 'x',estimator=sum,ci = None,legend = 'full',palette = 'rainbow')

# %%
sns.pointplot(x = df['month_funding'],hue = df['year_funding'],markers = 'x',estimator=sum,ci = None,legend = 'full',palette = 'rainbow')

# %%
df
# Out:
#                      Startup Name    Industry Vertical  \
# 0                          BYJU’S            Education
# 1                          Shuttl       Transportation
# 2                       Mamaearth            eCommerce
# 3    https://www.wealthbucket.in/              Finance
# 4                          Fashor  Fashion and Apparel
# ..                            ...                  ...
# 982                     Power2SME    Consumer Internet
# 983                     Applicate           Technology
# 984          Zebi (yet to launch)           Technology
# 985                         Truce                 FMCG
# 986                         Qriyo    Consumer Internet
#
#                                            SubVertical City  Location  \
# 0                                           E-learning      Bangalore
# 1                            App based shuttle service       Gurugram
# 2                Retailer of baby and toddler products      Bangalore
# ...

# %%
sns.pointplot(x = df['month_funding'],y = df['Amount in USD'],hue = df['year_funding'],markers = 'x',estimator=sum,ci = None,legend = 'full',palette = 'rainbow')

# %%
sns.pointplot(x = df['month_funding'],y = df['Amount in USD'],markers = 'x',estimator=sum,ci = None,legend = 'full',palette = 'rainbow')

# %%
df[df['Industry Vertical'] == 'Transportation'].sort_values('Amount in USD',ascending = False).head(2)
# Out:
#         Startup Name Industry Vertical SubVertical City  Location  \
# 74         BlackBuck    Transportation   Logistics      Bangalore
# 49  Rapido Bike Taxi    Transportation   Bike Taxi      Bangalore
#
#                                        Investors Name InvestmentnType  \
# 74  Goldman Sachs Investment Partners and Silicon ...        Series D
# 49                                 Westbridge Capital        Series B
#
#     Amount in USD  year_funding  month_funding
# 74      150000000          2019              6
# 49       55000000          2019              8
